# %%
from nltk.corpus.reader import WordListCorpusReader
from google.colab import files
uploaded = files.upload()
x = WordListCorpusReader(".", uploaded)
x.words()
# Out:
#      <input type="file" id="files-98b83b96-fe8b-49de-8745-c0173b39840e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98b83b96-fe8b-49de-8745-c0173b39840e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Corpus.txt to Corpus.txt
# ['The Board of Public Accountants has been given the green light to move forward with legislation that',
#  'would change Montana from a two-tier licensing state to a one-tier state. As of this newsletter, HB44',
#  'has passed the House and is awaiting Senate action. If passed, the Board would no longer issue a',
#  '“certificate only” but would require all applicants to qualify for a permit to practice (license) by meeting',
#  'the 4-Es – Education, Examination, Experience, & Ethics.',
#  'Currently, a “certificate only” is mostly used by foreign applicants who do not reside in the US and have',
#  'difficulty getting a US CPA to attest to their experience to meet the requirements for a permit to',
#  'practice, but Montana residence can and do apply for the “certificate only” too. The Board considers',
#  'the two-tier system confusing to the public and is trying to eliminate the confusion. The public doesn’t',
#  'necessarily understand the qualification and restrictions for a “certificate only” and assumes a CPA is a',
#  'CPA. Some “certificate only” licensees don’t necessarily understand the restrictions either.',
#  'The draft language contains a transition period for current “certificate only” licensees to obtain the',
#  'necessary experience to elevate to the permit to practice level of licensure. The experience',
#  'requirement to obtain a permit to practice is 2000 hours of accounting and auditing functions ordinarily',
#  'required in the practice of public accounting within the preceding 3 years. Experience can come from',
#  'private, governmental, academic, or public accounting work.',
#  'All applicable experience must be attested to by a US CPA in good standing with an active license at the',
#  'time of attestation. The CPA attesting to the experience does not need to be a supervisor, but must be',
#  'familiar with the applicant’s work and be able to attest that the work meets professional standards. The',
#  'Board may also consider military experience by evaluating information provided by the applicant’s',
#  'commanding officer, outlining the duties and responsibilities of the applicant while in military service. ']

# %% [markdown]
# ## Word Segmentation

# %%
import nltk
#nltk.download('punkt')
from nltk.tokenize import word_tokenize
#text = "God is Great! I won a lottery."
print(word_tokenize(x.raw()))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['The', 'Board', 'of', 'Public', 'Accountants', 'has', 'been', 'given', 'the', 'green', 'light', 'to', 'move', 'forward', 'with', 'legislation', 'that', 'would', 'change', 'Montana', 'from', 'a', 'two-tier', 'licensing', 'state', 'to', 'a', 'one-tier', 'state', '.', 'As', 'of', 'this', 'newsletter', ',', 'HB44', 'has', 'passed', 'the', 'House', 'and', 'is', 'awaiting', 'Senate', 'action', '.', 'If', 'passed', ',', 'the', 'Board', 'would', 'no', 'longer', 'issue', 'a', '“', 'certificate', 'only', '”', 'but', 'would', 'require', 'all', 'applicants', 'to', 'qualify', 'for', 'a', 'permit', 'to', 'practice', '(', 'license', ')', 'by', 'meeting', 'the', '4-Es', '–', 'Education', ',', 'Examination', ',', 'Experience', ',', '&', 'Ethics', '.', 'Currently', ',', 'a', '“', 'certificate', 'only', '”', 'is', 'mostly', 'used', 'by', 'foreign', 'applicants', 'who', 'do', 'not', 'reside', 'in', 'the', 'US', 'and', 'have', 'difficulty', 'getting', 'a', 'US', 'CPA', 'to', 'attest', 'to', 'their', 'experience', 'to', 'meet', 'the', 'requirements', 'for', 'a', 'permit', 'to', 'practice', ',', 'but', 'Montana', 'residence', 'can', 'and', 'do', 'apply', 'for', 'the', '“', 'certificate', 'only', '”', 'too', '.', 'The', 'Board', 'considers', 'the', 'two-tier', 'system', 'confusing', 'to', 'the', 'public', 'and', 'is', 'trying', 'to', 'eliminate', 'the', 'confusion', '.', 'The', 'public', 'doesn', '’', 't', 'necessarily', 'understand', 'the', 'qualification', 'and', 'restrictions', 'for', 'a', '“', 'certificate', 'only', '”', 'and', 'assumes', 'a', 'CPA', 'is', 'a', 'CPA', '.', 'Some', '“', 'certificate', 'only', '”', 'licensees', 'don', '’', 't', 'necessarily', 'understand', 'the', 'restrictions', 'either', '.', 'The', 'draft', 'language', 'contains', 'a', 'transition', 'period', 'for', 'current', '“', 'certificate', 'only', '”', 'licensees', 'to', 'obtain', 'the', 'necessary', 'experience', 'to', 'elevate', 'to', 'the', 'permit', 'to', 'practice', 'level', 'of', 'licensure', '.', 'The', 'experience', 'requirement', 'to', 'obtain', 'a', 'permit', 'to', 'practice', 'is', '2000', 'hours', 'of', 'accounting', 'and', 'auditing', 'functions', 'ordinarily', 'required', 'in', 'the', 'practice', 'of', 'public', 'accounting', 'within', 'the', 'preceding', '3', 'years', '.', 'Experience', 'can', 'come', 'from', 'private', ',', 'governmental', ',', 'academic', ',', 'or', 'public', 'accounting', 'work', '.', 'All', 'applicable', 'experience', 'must', 'be', 'attested', 'to', 'by', 'a', 'US', 'CPA', 'in', 'good', 'standing', 'with', 'an', 'active', 'license', 'at', 'the', 'time', 'of', 'attestation', '.', 'The', 'CPA', 'attesting', 'to', 'the', 'experience', 'does', 'not', 'need', 'to', 'be', 'a', 'supervisor', ',', 'but', 'must', 'be', 'familiar', 'with', 'the', 'applicant', '’', 's', 'work', 'and', 'be', 'able', 'to', 'attest', 'that', 'the', 'work', 'meets', 'professional', 'standards', '.', 'The', 'Board', 'may', 'also', 'consider', 'military', 'experience', 'by', 'evaluating', 'information', 'provided', 'by', 'the', 'applicant', '’', 's', 'commanding', 'officer', ',', 'outlining', 'the', 'duties', 'and', 'responsibilities', 'of', 'the', 'applicant', 'while', 'in', 'military', 'service', '.']

# %% [markdown]
# ## Sentence Segmentation

# %%
from nltk.tokenize import sent_tokenize
#text = "God is Great! I won a lottery."
text=x.raw()
print(sent_tokenize(text))
# Out:
# ['The Board of Public Accountants has been given the green light to move forward with legislation that\r\nwould change Montana from a two-tier licensing state to a one-tier state.', 'As of this newsletter, HB44\r\nhas passed the House and is awaiting Senate action.', 'If passed, the Board would no longer issue a\r\n“certificate only” but would require all applicants to qualify for a permit to practice (license) by meeting\r\nthe 4-Es – Education, Examination, Experience, & Ethics.', 'Currently, a “certificate only” is mostly used by foreign applicants who do not reside in the US and have\r\ndifficulty getting a US CPA to attest to their experience to meet the requirements for a permit to\r\npractice, but Montana residence can and do apply for the “certificate only” too.', 'The Board considers\r\nthe two-tier system confusing to the public and is trying to eliminate the confusion.', 'The public doesn’t\r\nnecessarily understand the qualification and restrictions for a “certificate only” and assumes a CPA is a\r\nCPA.', 'Some “certificate only” licensees don’t necessarily understand the restrictions either.', 'The draft language contains a transition period for current “certificate only” licensees to obtain the\r\nnecessary experience to elevate to the permit to practice level of licensure.', 'The experience\r\nrequirement to obtain a permit to practice is 2000 hours of accounting and auditing functions ordinarily\r\nrequired in the practice of public accounting within the preceding 3 years.', 'Experience can come from\r\nprivate, governmental, academic, or public accounting work.', 'All applicable experience must be attested to by a US CPA in good standing with an active license at the\r\ntime of attestation.', 'The CPA attesting to the experience does not need to be a supervisor, but must be\r\nfamiliar with the applicant’s work and be able to attest that the work meets professional standards.', 'The\r\nBoard may also consider military experience by evaluating information provided by the applicant’s\r\ncommanding officer, outlining the duties and responsibilities of the applicant while in military service.']

# %% [markdown]
# ## Convert To Lowercase

# %%
#text="HELLo bOY!!"
text=x.raw()
print(text.lower())
# Out:
# the board of public accountants has been given the green light to move forward with legislation that
# would change montana from a two-tier licensing state to a one-tier state. as of this newsletter, hb44
# has passed the house and is awaiting senate action. if passed, the board would no longer issue a
# “certificate only” but would require all applicants to qualify for a permit to practice (license) by meeting
# the 4-es – education, examination, experience, & ethics.
# currently, a “certificate only” is mostly used by foreign applicants who do not reside in the us and have
# difficulty getting a us cpa to attest to their experience to meet the requirements for a permit to
# practice, but montana residence can and do apply for the “certificate only” too. the board considers
# the two-tier system confusing to the public and is trying to eliminate the confusion. the public doesn’t
# necessarily understand the qualification and restrictions for a “certificate only” and assumes a cpa is a
# cpa. some “certificate only” licensees don’t necessarily understand the restrictions either.
# the draft language contains a transition period for current “certificate only” licensees to obtain the
# necessary experience to elevate to the permit to practice level of licensure. the experience
# requirement to obtain a permit to practice is 2000 hours of accounting and auditing functions ordinarily
# required in the practice of public accounting within the preceding 3 years. experience can come from
# private, governmental, academic, or public accounting work.
# all applicable experience must be attested to by a us cpa in good standing with an active license at the
# time of attestation. the cpa attesting to the experience does not need to be a supervisor, but must be
# familiar with the applicant’s work and be able to attest that the work meets professional standards. the
# board may also consider military experience by evaluating information provided by the applicant’s
# commanding officer, outlining the duties and responsibilities of the applicant while in military service.

# %% [markdown]
# ## Stop Words Removal

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

#example_sent = """This is a sample sentence,
#				showing off the stop words filtration."""

example_sent=x.raw();
#nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example_sent)

filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

filtered_sentence = []

for w in word_tokens:
	if w not in stop_words:
		filtered_sentence.append(w)

print(word_tokens)
print(filtered_sentence)
# Out:
# ['The', 'Board', 'of', 'Public', 'Accountants', 'has', 'been', 'given', 'the', 'green', 'light', 'to', 'move', 'forward', 'with', 'legislation', 'that', 'would', 'change', 'Montana', 'from', 'a', 'two-tier', 'licensing', 'state', 'to', 'a', 'one-tier', 'state', '.', 'As', 'of', 'this', 'newsletter', ',', 'HB44', 'has', 'passed', 'the', 'House', 'and', 'is', 'awaiting', 'Senate', 'action', '.', 'If', 'passed', ',', 'the', 'Board', 'would', 'no', 'longer', 'issue', 'a', '“', 'certificate', 'only', '”', 'but', 'would', 'require', 'all', 'applicants', 'to', 'qualify', 'for', 'a', 'permit', 'to', 'practice', '(', 'license', ')', 'by', 'meeting', 'the', '4-Es', '–', 'Education', ',', 'Examination', ',', 'Experience', ',', '&', 'Ethics', '.', 'Currently', ',', 'a', '“', 'certificate', 'only', '”', 'is', 'mostly', 'used', 'by', 'foreign', 'applicants', 'who', 'do', 'not', 'reside', 'in', 'the', 'US', 'and', 'have', 'difficulty', 'getting', 'a', 'US', 'CPA', 'to', 'attest', 'to', 'their', 'experience', 'to', 'meet', 'the', 'requirements', 'for', 'a', 'permit', 'to', 'practice', ',', 'but', 'Montana', 'residence', 'can', 'and', 'do', 'apply', 'for', 'the', '“', 'certificate', 'only', '”', 'too', '.', 'The', 'Board', 'considers', 'the', 'two-tier', 'system', 'confusing', 'to', 'the', 'public', 'and', 'is', 'trying', 'to', 'eliminate', 'the', 'confusion', '.', 'The', 'public', 'doesn', '’', 't', 'necessarily', 'understand', 'the', 'qualification', 'and', 'restrictions', 'for', 'a', '“', 'certificate', 'only', '”', 'and', 'assumes', 'a', 'CPA', 'is', 'a', 'CPA', '.', 'Some', '“', 'certificate', 'only', '”', 'licensees', 'don', '’', 't', 'necessarily', 'understand', 'the', 'restrictions', 'either', '.', 'The', 'draft', 'language', 'contains', 'a', 'transition', 'period', 'for', 'current', '“', 'certificate', 'only', '”', 'licensees', 'to', 'obtain', 'the', 'necessary', 'experience', 'to', 'elevate', 'to', 'the', 'permit', 'to', 'practice', 'level', 'of', 'licensure', '.', 'The', 'experience', 'requirement', 'to', 'obtain', 'a', 'permit', 'to', 'practice', 'is', '2000', 'hours', 'of', 'accounting', 'and', 'auditing', 'functions', 'ordinarily', 'required', 'in', 'the', 'practice', 'of', 'public', 'accounting', 'within', 'the', 'preceding', '3', 'years', '.', 'Experience', 'can', 'come', 'from', 'private', ',', 'governmental', ',', 'academic', ',', 'or', 'public', 'accounting', 'work', '.', 'All', 'applicable', 'experience', 'must', 'be', 'attested', 'to', 'by', 'a', 'US', 'CPA', 'in', 'good', 'standing', 'with', 'an', 'active', 'license', 'at', 'the', 'time', 'of', 'attestation', '.', 'The', 'CPA', 'attesting', 'to', 'the', 'experience', 'does', 'not', 'need', 'to', 'be', 'a', 'supervisor', ',', 'but', 'must', 'be', 'familiar', 'with', 'the', 'applicant', '’', 's', 'work', 'and', 'be', 'able', 'to', 'attest', 'that', 'the', 'work', 'meets', 'professional', 'standards', '.', 'The', 'Board', 'may', 'also', 'consider', 'military', 'experience', 'by', 'evaluating', 'information', 'provided', 'by', 'the', 'applicant', '’', 's', 'commanding', 'officer', ',', 'outlining', 'the', 'duties', 'and', 'responsibilities', 'of', 'the', 'applicant', 'while', 'in', 'military', 'service', '.']
# ['The', 'Board', 'Public', 'Accountants', 'given', 'green', 'light', 'move', 'forward', 'legislation', 'would', 'change', 'Montana', 'two-tier', 'licensing', 'state', 'one-tier', 'state', '.', 'As', 'newsletter', ',', 'HB44', 'passed', 'House', 'awaiting', 'Senate', 'action', '.', 'If', 'passed', ',', 'Board', 'would', 'longer', 'issue', '“', 'certificate', '”', 'would', 'require', 'applicants', 'qualify', 'permit', 'practice', '(', 'license', ')', 'meeting', '4-Es', '–', 'Education', ',', 'Examination', ',', 'Experience', ',', '&', 'Ethics', '.', 'Currently', ',', '“', 'certificate', '”', 'mostly', 'used', 'foreign', 'applicants', 'reside', 'US', 'difficulty', 'getting', 'US', 'CPA', 'attest', 'experience', 'meet', 'requirements', 'permit', 'practice', ',', 'Montana', 'residence', 'apply', '“', 'certificate', '”', '.', 'The', 'Board', 'considers', 'two-tier', 'system', 'confusing', 'public', 'trying', 'eliminate', 'confusion', '.', 'The', 'public', '’', 'necessarily', 'understand', 'qualification', 'restrictions', '“', 'certificate', '”', 'assumes', 'CPA', 'CPA', '.', 'Some', '“', 'certificate', '”', 'licensees', '’', 'necessarily', 'understand', 'restrictions', 'either', '.', 'The', 'draft', 'language', 'contains', 'transition', 'period', 'current', '“', 'certificate', '”', 'licensees', 'obtain', 'necessary', 'experience', 'elevate', 'permit', 'practice', 'level', 'licensure', '.', 'The', 'experience', 'requirement', 'obtain', 'permit', 'practice', '2000', 'hours', 'accounting', 'auditing', 'functions', 'ordinarily', 'required', 'practice', 'public', 'accounting', 'within', 'preceding', '3', 'years', '.', 'Experience', 'come', 'private', ',', 'governmental', ',', 'academic', ',', 'public', 'accounting', 'work', '.', 'All', 'applicable', 'experience', 'must', 'attested', 'US', 'CPA', 'good', 'standing', 'active', 'license', 'time', 'attestation', '.', 'The', 'CPA', 'attesting', 'experience', 'need', 'supervisor', ',', 'must', 'familiar', 'applicant', '’', 'work', 'able', 'attest', 'work', 'meets', 'professional', 'standards', '.', 'The', 'Board', 'may', 'also', 'consider', 'military', 'experience', 'evaluating', 'information', 'provided', 'applicant', '’', 'commanding', 'officer', ',', 'outlining', 'duties', 'responsibilities', 'applicant', 'military', 'service', '.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Stemming

# %%
# import these modules
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

ps = PorterStemmer()

# choose some words to be stemmed
#words = ["program", "programs", "programmer", "programming", "programmers"]
k=word_tokenize(x.raw())
for w in k:
	print(w, " : ", ps.stem(w))
# Out:
# The  :  the
# Board  :  board
# of  :  of
# Public  :  public
# Accountants  :  account
# has  :  ha
# been  :  been
# given  :  given
# the  :  the
# green  :  green
# light  :  light
# to  :  to
# move  :  move
# forward  :  forward
# with  :  with
# legislation  :  legisl
# that  :  that
# would  :  would
# change  :  chang
# Montana  :  montana
# from  :  from
# a  :  a
# two-tier  :  two-tier
# licensing  :  licens
# state  :  state
# to  :  to
# a  :  a
# one-tier  :  one-ti
# state  :  state
# .  :  .
# As  :  as
# of  :  of
# this  :  thi
# newsletter  :  newslett
# ,  :  ,
# HB44  :  hb44
# has  :  ha
# passed  :  pass
# the  :  the
# House  :  hous
# and  :  and
# is  :  is
# awaiting  :  await
# Senate  :  senat
# action  :  action
# .  :  .
# If  :  if
# passed  :  pass
# ,  :  ,
# the  :  the
# Board  :  board
# would  :  would
# no  :  no
# longer  :  longer
# issue  :  issu
# a  :  a
# “  :  “
# certificate  :  certif
# only  :  onli
# ”  :  ”
# but  :  but
# would  :  would
# require  :  requir
# all  :  all
# applicants  :  applic
# to  :  to
# qualify  :  qualifi
# for  :  for
# a  :  a
# permit  :  permit
# to  :  to
# practice  :  practic
# (  :  (
# license  :  licens
# )  :  )
# by  :  by
# meeting  :  meet
# the  :  the
# 4-Es  :  4-e
# –  :  –
# Education  :  educ
# ,  :  ,
# Examination  :  examin
# ,  :  ,
# Experience  :  experi
# ,  :  ,
# &  :  &
# Ethics  :  ethic
# .  :  .
# Currently  :  current
# ,  :  ,
# a  :  a
# “  :  “
# certificate  :  certif
# only  :  onli
# ”  :  ”
# is  :  is
# mostly  :  mostli
# used  :  use
# by  :  by
# foreign  :  foreign
# applicants  :  applic
# who  :  who
# do  :  do
# not  :  not
# reside  :  resid
# in  :  in
# the  :  the
# US  :  us
# and  :  and
# have  :  have
# difficulty  :  difficulti
# getting  :  get
# a  :  a
# US  :  us
# CPA  :  cpa
# to  :  to
# attest  :  attest
# to  :  to
# their  :  their
# experience  :  experi
# to  :  to
# meet  :  meet
# the  :  the
# requirements  :  requir
# for  :  for
# a  :  a
# permit  :  permit
# to  :  to
# practice  :  practic
# ,  :  ,
# but  :  but
# Montana  :  montana
# residence  :  resid
# can  :  can
# and  :  and
# do  :  do
# apply  :  appli
# for  :  for
# the  :  the
# “  :  “
# certificate  :  certif
# only  :  onli
# ”  :  ”
# too  :  too
# .  :  .
# The  :  the
# Board  :  board
# considers  :  consid
# the  :  the
# two-tier  :  two-tier
# system  :  system
# confusing  :  confus
# to  :  to
# the  :  the
# public  :  public
# and  :  and
# is  :  is
# trying  :  tri
# to  :  to
# eliminate  :  elimin
# the  :  the
# confusion  :  confus
# .  :  .
# The  :  the
# public  :  public
# doesn  :  doesn
# ’  :  ’
# t  :  t
# necessarily  :  necessarili
# understand  :  understand
# the  :  the
# qualification  :  qualif
# and  :  and
# restrictions  :  restrict
# for  :  for
# a  :  a
# “  :  “
# certificate  :  certif
# only  :  onli
# ”  :  ”
# and  :  and
# assumes  :  assum
# a  :  a
# CPA  :  cpa
# is  :  is
# a  :  a
# CPA  :  cpa
# .  :  .
# Some  :  some
# “  :  “
# certificate  :  certif
# only  :  onli
# ”  :  ”
# licensees  :  license
# don  :  don
# ’  :  ’
# t  :  t
# necessarily  :  necessarili
# understand  :  understand
# the  :  the
# restrictions  :  restrict
# either  :  either
# .  :  .
# The  :  the
# draft  :  draft
# language  :  languag
# contains  :  contain
# a  :  a
# transition  :  transit
# period  :  period
# for  :  for
# current  :  current
# “  :  “
# certificate  :  certif
# only  :  onli
# ”  :  ”
# licensees  :  license
# to  :  to
# obtain  :  obtain
# the  :  the
# necessary  :  necessari
# experience  :  experi
# to  :  to
# elevate  :  elev
# to  :  to
# the  :  the
# permit  :  permit
# to  :  to
# practice  :  practic
# level  :  level
# of  :  of
# licensure  :  licensur
# .  :  .
# The  :  the
# experience  :  experi
# requirement  :  requir
# to  :  to
# obtain  :  obtain
# a  :  a
# permit  :  permit
# to  :  to
# practice  :  practic
# is  :  is
# 2000  :  2000
# hours  :  hour
# of  :  of
# accounting  :  account
# and  :  and
# auditing  :  audit
# functions  :  function
# ordinarily  :  ordinarili
# required  :  requir
# in  :  in
# the  :  the
# practice  :  practic
# of  :  of
# public  :  public
# accounting  :  account
# within  :  within
# the  :  the
# preceding  :  preced
# 3  :  3
# years  :  year
# .  :  .
# Experience  :  experi
# can  :  can
# come  :  come
# from  :  from
# private  :  privat
# ,  :  ,
# governmental  :  government
# ,  :  ,
# academic  :  academ
# ,  :  ,
# or  :  or
# public  :  public
# accounting  :  account
# work  :  work
# .  :  .
# All  :  all
# applicable  :  applic
# experience  :  experi
# must  :  must
# be  :  be
# attested  :  attest
# to  :  to
# by  :  by
# a  :  a
# US  :  us
# CPA  :  cpa
# in  :  in
# good  :  good
# standing  :  stand
# with  :  with
# an  :  an
# active  :  activ
# license  :  licens
# at  :  at
# the  :  the
# time  :  time
# of  :  of
# attestation  :  attest
# .  :  .
# The  :  the
# CPA  :  cpa
# attesting  :  attest
# to  :  to
# the  :  the
# experience  :  experi
# does  :  doe
# not  :  not
# need  :  need
# to  :  to
# be  :  be
# a  :  a
# supervisor  :  supervisor
# ,  :  ,
# but  :  but
# must  :  must
# be  :  be
# familiar  :  familiar
# with  :  with
# the  :  the
# applicant  :  applic
# ’  :  ’
# s  :  s
# work  :  work
# and  :  and
# be  :  be
# able  :  abl
# to  :  to
# attest  :  attest
# that  :  that
# the  :  the
# work  :  work
# meets  :  meet
# professional  :  profession
# standards  :  standard
# .  :  .
# The  :  the
# Board  :  board
# may  :  may
# also  :  also
# consider  :  consid
# military  :  militari
# experience  :  experi
# by  :  by
# evaluating  :  evalu
# information  :  inform
# provided  :  provid
# by  :  by
# the  :  the
# applicant  :  applic
# ’  :  ’
# s  :  s
# commanding  :  command
# officer  :  offic
# ,  :  ,
# outlining  :  outlin
# the  :  the
# duties  :  duti
# and  :  and
# responsibilities  :  respons
# of  :  of
# the  :  the
# applicant  :  applic
# while  :  while
# in  :  in
# military  :  militari
# service  :  servic
# .  :  .

# %% [markdown]
# ## Lemmatization

# %%
#nltk.download('wordnet')
#nltk.download('omw-1.4')
# import these modules
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

#print("rocks :", lemmatizer.lemmatize("rocks"))
#print("corpora :", lemmatizer.lemmatize("corpora"))

# a denotes adjective in "pos"
#print("better :", lemmatizer.lemmatize("better", pos ="a"))

for w in k:
	print(w, " : ", lemmatizer.lemmatize(w))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# The  :  The
# Board  :  Board
# of  :  of
# Public  :  Public
# Accountants  :  Accountants
# has  :  ha
# been  :  been
# given  :  given
# the  :  the
# green  :  green
# light  :  light
# to  :  to
# move  :  move
# forward  :  forward
# with  :  with
# legislation  :  legislation
# that  :  that
# would  :  would
# change  :  change
# Montana  :  Montana
# from  :  from
# a  :  a
# two-tier  :  two-tier
# licensing  :  licensing
# state  :  state
# to  :  to
# a  :  a
# one-tier  :  one-tier
# state  :  state
# .  :  .
# As  :  As
# of  :  of
# this  :  this
# newsletter  :  newsletter
# ,  :  ,
# HB44  :  HB44
# has  :  ha
# passed  :  passed
# the  :  the
# House  :  House
# and  :  and
# is  :  is
# awaiting  :  awaiting
# Senate  :  Senate
# action  :  action
# .  :  .
# If  :  If
# passed  :  passed
# ,  :  ,
# the  :  the
# Board  :  Board
# would  :  would
# no  :  no
# longer  :  longer
# issue  :  issue
# a  :  a
# “  :  “
# certificate  :  certificate
# only  :  only
# ”  :  ”
# but  :  but
# would  :  would
# require  :  require
# all  :  all
# applicants  :  applicant
# to  :  to
# qualify  :  qualify
# for  :  for
# a  :  a
# permit  :  permit
# to  :  to
# practice  :  practice
# (  :  (
# license  :  license
# )  :  )
# by  :  by
# meeting  :  meeting
# the  :  the
# 4-Es  :  4-Es
# –  :  –
# Education  :  Education
# ,  :  ,
# Examination  :  Examination
# ,  :  ,
# Experience  :  Experience
# ,  :  ,
# &  :  &
# Ethics  :  Ethics
# .  :  .
# Currently  :  Currently
# ,  :  ,
# a  :  a
# “  :  “
# certificate  :  certificate
# only  :  only
# ”  :  ”
# is  :  is
# mostly  :  mostly
# used  :  used
# by  :  by
# foreign  :  foreign
# applicants  :  applicant
# who  :  who
# do  :  do
# not  :  not
# reside  :  reside
# in  :  in
# the  :  the
# US  :  US
# and  :  and
# have  :  have
# difficulty  :  difficulty
# getting  :  getting
# a  :  a
# US  :  US
# CPA  :  CPA
# to  :  to
# attest  :  attest
# to  :  to
# their  :  their
# experience  :  experience
# to  :  to
# meet  :  meet
# the  :  the
# requirements  :  requirement
# for  :  for
# a  :  a
# permit  :  permit
# to  :  to
# practice  :  practice
# ,  :  ,
# but  :  but
# Montana  :  Montana
# residence  :  residence
# can  :  can
# and  :  and
# do  :  do
# apply  :  apply
# for  :  for
# the  :  the
# “  :  “
# certificate  :  certificate
# only  :  only
# ”  :  ”
# too  :  too
# .  :  .
# The  :  The
# Board  :  Board
# considers  :  considers
# the  :  the
# two-tier  :  two-tier
# system  :  system
# confusing  :  confusing
# to  :  to
# the  :  the
# public  :  public
# and  :  and
# is  :  is
# trying  :  trying
# to  :  to
# eliminate  :  eliminate
# the  :  the
# confusion  :  confusion
# .  :  .
# The  :  The
# public  :  public
# doesn  :  doesn
# ’  :  ’
# t  :  t
# necessarily  :  necessarily
# understand  :  understand
# the  :  the
# qualification  :  qualification
# and  :  and
# restrictions  :  restriction
# for  :  for
# a  :  a
# “  :  “
# certificate  :  certificate
# only  :  only
# ”  :  ”
# and  :  and
# assumes  :  assumes
# a  :  a
# CPA  :  CPA
# is  :  is
# a  :  a
# CPA  :  CPA
# .  :  .
# Some  :  Some
# “  :  “
# certificate  :  certificate
# only  :  only
# ”  :  ”
# licensees  :  licensee
# don  :  don
# ’  :  ’
# t  :  t
# necessarily  :  necessarily
# understand  :  understand
# the  :  the
# restrictions  :  restriction
# either  :  either
# .  :  .
# The  :  The
# draft  :  draft
# language  :  language
# contains  :  contains
# a  :  a
# transition  :  transition
# period  :  period
# for  :  for
# current  :  current
# “  :  “
# certificate  :  certificate
# only  :  only
# ”  :  ”
# licensees  :  licensee
# to  :  to
# obtain  :  obtain
# the  :  the
# necessary  :  necessary
# experience  :  experience
# to  :  to
# elevate  :  elevate
# to  :  to
# the  :  the
# permit  :  permit
# to  :  to
# practice  :  practice
# level  :  level
# of  :  of
# licensure  :  licensure
# .  :  .
# The  :  The
# experience  :  experience
# requirement  :  requirement
# to  :  to
# obtain  :  obtain
# a  :  a
# permit  :  permit
# to  :  to
# practice  :  practice
# is  :  is
# 2000  :  2000
# hours  :  hour
# of  :  of
# accounting  :  accounting
# and  :  and
# auditing  :  auditing
# functions  :  function
# ordinarily  :  ordinarily
# required  :  required
# in  :  in
# the  :  the
# practice  :  practice
# of  :  of
# public  :  public
# accounting  :  accounting
# within  :  within
# the  :  the
# preceding  :  preceding
# 3  :  3
# years  :  year
# .  :  .
# Experience  :  Experience
# can  :  can
# come  :  come
# from  :  from
# private  :  private
# ,  :  ,
# governmental  :  governmental
# ,  :  ,
# academic  :  academic
# ,  :  ,
# or  :  or
# public  :  public
# accounting  :  accounting
# work  :  work
# .  :  .
# All  :  All
# applicable  :  applicable
# experience  :  experience
# must  :  must
# be  :  be
# attested  :  attested
# to  :  to
# by  :  by
# a  :  a
# US  :  US
# CPA  :  CPA
# in  :  in
# good  :  good
# standing  :  standing
# with  :  with
# an  :  an
# active  :  active
# license  :  license
# at  :  at
# the  :  the
# time  :  time
# of  :  of
# attestation  :  attestation
# .  :  .
# The  :  The
# CPA  :  CPA
# attesting  :  attesting
# to  :  to
# the  :  the
# experience  :  experience
# does  :  doe
# not  :  not
# need  :  need
# to  :  to
# be  :  be
# a  :  a
# supervisor  :  supervisor
# ,  :  ,
# but  :  but
# must  :  must
# be  :  be
# familiar  :  familiar
# with  :  with
# the  :  the
# applicant  :  applicant
# ’  :  ’
# s  :  s
# work  :  work
# and  :  and
# be  :  be
# able  :  able
# to  :  to
# attest  :  attest
# that  :  that
# the  :  the
# work  :  work
# meets  :  meet
# professional  :  professional
# standards  :  standard
# .  :  .
# The  :  The
# Board  :  Board
# may  :  may
# also  :  also
# consider  :  consider
# military  :  military
# experience  :  experience
# by  :  by
# evaluating  :  evaluating
# information  :  information
# provided  :  provided
# by  :  by
# the  :  the
# applicant  :  applicant
# ’  :  ’
# s  :  s
# commanding  :  commanding
# officer  :  officer
# ,  :  ,
# outlining  :  outlining
# the  :  the
# duties  :  duty
# and  :  and
# responsibilities  :  responsibility
# of  :  of
# the  :  the
# applicant  :  applicant
# while  :  while
# in  :  in
# military  :  military
# service  :  service
# .  :  .

# %% [markdown]
# ## POS Tagging

# %%
import nltk
#nltk.download('stopwords')
#nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
stop_words = set(stopwords.words('english'))


#txt = """My Name is James Bond"""

# sent_tokenize is one of instances of
# PunktSentenceTokenizer from the nltk.tokenize.punkt module

tokenized = sent_tokenize(x.raw())
for i in tokenized:
	
	# Word tokenizers is used to find the words
	# and punctuation in a string
	wordsList = nltk.word_tokenize(i)

	# removing stop words from wordList
	wordsList = [w for w in wordsList if not w in stop_words]

	# Using a Tagger. Which is part-of-speech
	# tagger or POS-tagger.
	tagged = nltk.pos_tag(wordsList)

	print(tagged)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('The', 'DT'), ('Board', 'NNP'), ('Public', 'NNP'), ('Accountants', 'NNP'), ('given', 'VBN'), ('green', 'JJ'), ('light', 'JJ'), ('move', 'NN'), ('forward', 'NN'), ('legislation', 'NN'), ('would', 'MD'), ('change', 'VB'), ('Montana', 'NNP'), ('two-tier', 'JJ'), ('licensing', 'NN'), ('state', 'NN'), ('one-tier', 'JJ'), ('state', 'NN'), ('.', '.')]
# [('As', 'IN'), ('newsletter', 'NN'), (',', ','), ('HB44', 'NNP'), ('passed', 'VBD'), ('House', 'NNP'), ('awaiting', 'VBG'), ('Senate', 'NNP'), ('action', 'NN'), ('.', '.')]
# [('If', 'IN'), ('passed', 'VBN'), (',', ','), ('Board', 'NNP'), ('would', 'MD'), ('longer', 'RB'), ('issue', 'VB'), ('“', 'NNP'), ('certificate', 'NN'), ('”', 'NNP'), ('would', 'MD'), ('require', 'VB'), ('applicants', 'NNS'), ('qualify', 'VB'), ('permit', 'NN'), ('practice', 'NN'), ('(', '('), ('license', 'NN'), (')', ')'), ('meeting', 'NN'), ('4-Es', 'JJ'), ('–', 'NN'), ('Education', 'NNP'), (',', ','), ('Examination', 'NNP'), (',', ','), ('Experience', 'NNP'), (',', ','), ('&', 'CC'), ('Ethics', 'NNS'), ('.', '.')]
# [('Currently', 'RB'), (',', ','), ('“', 'NNP'), ('certificate', 'NN'), ('”', 'NNP'), ('mostly', 'RB'), ('used', 'VBD'), ('foreign', 'JJ'), ('applicants', 'NNS'), ('reside', 'VBP'), ('US', 'NNP'), ('difficulty', 'NN'), ('getting', 'VBG'), ('US', 'NNP'), ('CPA', 'NNP'), ('attest', 'JJS'), ('experience', 'NN'), ('meet', 'NN'), ('requirements', 'NNS'), ('permit', 'VBP'), ('practice', 'NN'), (',', ','), ('Montana', 'NNP'), ('residence', 'NN'), ('apply', 'NN'), ('“', 'NNP'), ('certificate', 'NN'), ('”', 'NN'), ('.', '.')]
# [('The', 'DT'), ('Board', 'NNP'), ('considers', 'VBZ'), ('two-tier', 'JJ'), ('system', 'NN'), ('confusing', 'VBG'), ('public', 'JJ'), ('trying', 'VBG'), ('eliminate', 'JJ'), ('confusion', 'NN'), ('.', '.')]
# [('The', 'DT'), ('public', 'JJ'), ('’', 'NNP'), ('necessarily', 'RB'), ('understand', 'VB'), ('qualification', 'NN'), ('restrictions', 'NNS'), ('“', 'VBP'), ('certificate', 'JJ'), ('”', 'NNP'), ('assumes', 'VBZ'), ('CPA', 'NNP'), ('CPA', 'NNP'), ('.', '.')]
# [('Some', 'DT'), ('“', 'JJ'), ('certificate', 'NN'), ('”', 'NN'), ('licensees', 'VBZ'), ('’', 'VBP'), ('necessarily', 'RB'), ('understand', 'VB'), ('restrictions', 'NNS'), ('either', 'DT'), ('.', '.')]
# [('The', 'DT'), ('draft', 'NN'), ('language', 'NN'), ('contains', 'VBZ'), ('transition', 'JJ'), ('period', 'NN'), ('current', 'JJ'), ('“', 'JJ'), ('certificate', 'NN'), ('”', 'NN'), ('licensees', 'VBZ'), ('obtain', 'VB'), ('necessary', 'JJ'), ('experience', 'NN'), ('elevate', 'NN'), ('permit', 'NN'), ('practice', 'NN'), ('level', 'NN'), ('licensure', 'NN'), ('.', '.')]
# [('The', 'DT'), ('experience', 'NN'), ('requirement', 'NN'), ('obtain', 'VB'), ('permit', 'NN'), ('practice', 'NN'), ('2000', 'CD'), ('hours', 'NNS'), ('accounting', 'VBG'), ('auditing', 'VBG'), ('functions', 'NNS'), ('ordinarily', 'RB'), ('required', 'VBN'), ('practice', 'NN'), ('public', 'JJ'), ('accounting', 'NN'), ('within', 'IN'), ('preceding', 'VBG'), ('3', 'CD'), ('years', 'NNS'), ('.', '.')]
# [('Experience', 'NN'), ('come', 'VB'), ('private', 'JJ'), (',', ','), ('governmental', 'JJ'), (',', ','), ('academic', 'JJ'), (',', ','), ('public', 'JJ'), ('accounting', 'NN'), ('work', 'NN'), ('.', '.')]
# [('All', 'DT'), ('applicable', 'JJ'), ('experience', 'NN'), ('must', 'MD'), ('attested', 'VB'), ('US', 'NNP'), ('CPA', 'NNP'), ('good', 'JJ'), ('standing', 'VBG'), ('active', 'JJ'), ('license', 'NN'), ('time', 'NN'), ('attestation', 'NN'), ('.', '.')]
# [('The', 'DT'), ('CPA', 'NNP'), ('attesting', 'VBG'), ('experience', 'NN'), ('need', 'NN'), ('supervisor', 'NN'), (',', ','), ('must', 'MD'), ('familiar', 'JJ'), ('applicant', 'JJ'), ('’', 'NN'), ('work', 'NN'), ('able', 'JJ'), ('attest', 'JJ'), ('work', 'NN'), ('meets', 'NNS'), ('professional', 'JJ'), ('standards', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('Board', 'NNP'), ('may', 'MD'), ('also', 'RB'), ('consider', 'VB'), ('military', 'JJ'), ('experience', 'NN'), ('evaluating', 'VBG'), ('information', 'NN'), ('provided', 'VBD'), ('applicant', 'JJ'), ('’', 'JJ'), ('commanding', 'VBG'), ('officer', 'NN'), (',', ','), ('outlining', 'VBG'), ('duties', 'NNS'), ('responsibilities', 'NNS'), ('applicant', 'VBP'), ('military', 'JJ'), ('service', 'NN'), ('.', '.')]
